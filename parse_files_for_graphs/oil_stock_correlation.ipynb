# %%
import pandas as pd
df = pd.read_csv("data/commodity.csv")
df.head()
# Out:
#       Value        Date        Sub-Sector Super Region  \
# 0  393834.0  2020-08-07  COMMODITY PRICES  GLOBAL DATA
# 1  865736.0  2018-03-07  COMMODITY PRICES  GLOBAL DATA
# 2  345299.0  2021-01-25  COMMODITY PRICES  GLOBAL DATA
# 3  353417.0  2020-08-06  COMMODITY PRICES  GLOBAL DATA
# 4  626407.0  2018-03-06  COMMODITY PRICES  GLOBAL DATA
#
#     Commodity And Exchange Frequency              Source Indicator
# 0  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 1  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 2  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 3  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 4  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME

# %%
wti_df = df[df["Commodity And Exchange"] == "WTI CRUDE OIL (DOLLARS PER BARREL)"] 
# nymex_df = df[df["Commodity And Exchange"] == "NYMEX CRUDE OIL FUTURES"]
wti_df.head()
# Out:
#        Value        Date        Sub-Sector Super Region  \
# 15000  41.16  2020-08-07  COMMODITY PRICES  GLOBAL DATA
# 15001  61.09  2018-03-07  COMMODITY PRICES  GLOBAL DATA
# 15002  52.78  2021-01-25  COMMODITY PRICES  GLOBAL DATA
# 15003  41.93  2020-08-06  COMMODITY PRICES  GLOBAL DATA
# 15004  62.54  2018-03-06  COMMODITY PRICES  GLOBAL DATA
#
#                    Commodity And Exchange Frequency              Source  \
# 15000  WTI CRUDE OIL (DOLLARS PER BARREL)     DAILY  COMMODITY EXCHANGE
# 15001  WTI CRUDE OIL (DOLLARS PER BARREL)     DAILY  COMMODITY EXCHANGE
# 15002  WTI CRUDE OIL (DOLLARS PER BARREL)     DAILY  COMMODITY EXCHANGE
# 15003  WTI CRUDE OIL (DOLLARS PER BARREL)     DAILY  COMMODITY EXCHANGE
# 15004  WTI CRUDE OIL (DOLLARS PER BARREL)     DAILY  COMMODITY EXCHANGE
#
#           Indicator
# 15000  PRICE IN USD
# 15001  PRICE IN USD
# 15002  PRICE IN USD
# 15003  PRICE IN USD
# 15004  PRICE IN USD

# %%
wti_df = wti_df.iloc[:, [0,1]]
wti_df.head()
# Out:
#        Value        Date
# 15000  41.16  2020-08-07
# 15001  61.09  2018-03-07
# 15002  52.78  2021-01-25
# 15003  41.93  2020-08-06
# 15004  62.54  2018-03-06

# %%
wti_df = wti_df.sort_values(by="Date")
wti_df.head()
# Out:
#        Value        Date
# 15224  48.75  2017-03-09
# 15771  48.05  2017-03-10
# 15769  47.95  2017-03-13
# 15775  47.24  2017-03-14
# 15774  48.34  2017-03-15

# %%
df = pd.read_csv("data/global_stock_exchange.csv")
df.head()
# Out:
#    Value        Date Super Region Ticker Time Level        Source  \
# 0  36.67  2020-08-07  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 1  67.68  2018-03-07  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 2  46.23  2021-01-25  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 3  35.73  2020-08-06  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 4  67.39  2018-03-06  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
#
#                        Stock Name                  Sub-Sector Stock Attribute  \
# 0  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 1  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 2  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 3  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 4  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
#
#   Currency            Data Provider                          Stock Exchange  \
# 0      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 1      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 2      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 3      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 4      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
#
#            Location
# 0  AMERICA-NEW_YORK
# 1  AMERICA-NEW_YORK
# 2  AMERICA-NEW_YORK
# 3  AMERICA-NEW_YORK
# 4  AMERICA-NEW_YORK

# %%
companies = df["Stock Name"].unique()
dfs = []
for c in companies:
#     print(c)
    dfs.append(df[df["Stock Name"] == c])

dfs[0].head()
# Out:
#    Value        Date Super Region Ticker Time Level        Source  \
# 0  36.67  2020-08-07  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 1  67.68  2018-03-07  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 2  46.23  2021-01-25  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 3  35.73  2020-08-06  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 4  67.39  2018-03-06  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
#
#                        Stock Name                  Sub-Sector Stock Attribute  \
# 0  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 1  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 2  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 3  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 4  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
#
#   Currency            Data Provider                          Stock Exchange  \
# 0      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 1      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 2      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 3      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 4      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
#
#            Location
# 0  AMERICA-NEW_YORK
# 1  AMERICA-NEW_YORK
# 2  AMERICA-NEW_YORK
# 3  AMERICA-NEW_YORK
# 4  AMERICA-NEW_YORK

# %%
for i in range(len(dfs)):
    dfs[i] = dfs[i].loc[:, ["Value", "Date"]]

dfs[0].head()
# Out:
#    Value        Date
# 0  36.67  2020-08-07
# 1  67.68  2018-03-07
# 2  46.23  2021-01-25
# 3  35.73  2020-08-06
# 4  67.39  2018-03-06

# %%
merge_dfs = []
for df in dfs:
    merge_dfs.append(wti_df.merge(df, on="Date"))
# y is stock price. (verified)
merge_dfs[0].set_index('Date').loc['2020-07-08':'2020-08-08', :]
# Out:
#             Value_x  Value_y
# Date
# 2020-07-08    40.91    34.15
# 2020-07-09    39.64    33.35
# 2020-07-10    40.56    36.20
# 2020-07-13    40.06    35.31
# 2020-07-14    40.30    36.20
# 2020-07-15    41.20    37.57
# 2020-07-16    40.74    37.39
# 2020-07-17    40.55    37.93
# 2020-07-20    40.83    36.75
# 2020-07-21    41.76    38.54
# 2020-07-22    41.88    38.73
# 2020-07-23    40.99    38.88
# 2020-07-24    41.23    38.70
# 2020-07-27    41.46    38.52
# 2020-07-28    40.89    38.12
# 2020-07-29    41.13    39.91
# 2020-07-30    39.85    38.08
# 2020-07-31    40.10    38.20
# 2020-08-03    40.83    38.57
# 2020-08-04    41.67    37.69
# 2020-08-05    42.25    36.43
# 2020-08-06    41.93    35.73
# 2020-08-07    41.16    36.67

# %%
for merge_df in merge_dfs:
    merge_df = merge_df.set_index("Date")
    merge_df.plot()

# %%
import matplotlib.pyplot as plt
for merge_df in merge_dfs:
    oil_price = merge_df["Value_x"][:10]
    stock_price = merge_df["Value_y"][:10]
    lag = 0
    n = len(oil_price)
    oil_price_l = oil_price[lag:]
    stock_price_l = stock_price[:n-lag]
    
    oil_price_l = oil_price_l.reset_index()
    stock_price_l = stock_price_l.reset_index()
    
    del oil_price_l['index']
    del stock_price_l['index']
    
#     print(oil_price_l)
#     print(stock_price_l)
    plt.figure()
    l2,  = plt.plot(oil_price_l)
    l1,  = plt.plot(stock_price_l)
    plt.legend([l1, l2], ["stock", "oil"])

# %%
merge_df.head()
import matplotlib.pyplot as plt
for merge_df in merge_dfs:
    plt.figure()
    plt.scatter(merge_df.Value_x, merge_df.Value_y)

# %%
for merge_df in merge_dfs:
    oil_price = merge_df["Value_x"][:100]
    stock_price = merge_df["Value_y"][:100]
    print(oil_price.corr(stock_price))
# Out:
# -0.33934873819508776
# 0.25186841666895976
# -0.4277429800058268
# -0.24403116394795832
# 0.6621454043665127
# 0.18264467549706737
# 0.45874824132801745
# 0.6944278608316137
# 0.7372775384222668
# 0.7516692931148052

# %%
merge_df = merge_dfs[1]
oil_price = merge_df["Value_x"]
stock_price = merge_df["Value_y"]

# %%
def find_lagged_correlation(series1, series2, lag):
    assert len(series1) == len(series2)
    n = len(series1)
    s1 = series1[:n-lag]
    s2 = series2[lag:n]
    assert len(s1) == len(s2)
    return s1.corr(s2)

# %%
print_stats = False
plot_stats = True
c = 1
for merge_df in merge_dfs:
    oil_price = merge_df["Value_x"][:50]
    stock_price = merge_df["Value_y"][:50]
#     print(len(oil_price))
    print_stats and print("df: {}".format(c))
    print_stats and  print()
    c += 1 
    corrs = []
    for lag in range(7):
        corr = find_lagged_correlation(oil_price, stock_price, lag)
        corrs.append(corr)
        print_stats and print('lag: {}, corr: {}'.format(lag, corr))
    
    print_stats and print()
    plot_stats and plt.figure()
    plot_stats and plt.plot(corrs)
